# %%
print("hello world")
# Out:
# hello world

# %%
print(5)
# Out:
# 5

# %%
print(-10)
# Out:
# -10

# %%
print(3.14)
# Out:
# 3.14

# %%
print(1000)
# Out:
# 1000

# %%
print(5+3)
# Out:
# 8

# %%
print(2*8)
# Out:
# 16

# %%
print(3*(3+1))
# Out:
# 12

# %%
print("풍선")
# Out:
# 풍선

# %%
print("나비")
# Out:
# 나비

# %%
print("ㅋㅋㅋㅋㅋㅋㅋㅋㅋ")
# Out:
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋ

# %%
print("ㅋ"*9)
# Out:
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋ

# %%
# boolean 자료형
# 참 / 거짓

# %%
print(5 > 10)
# Out:
# False

# %%
print(5 < 10)
# Out:
# True

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
print(not True)
# Out:
# False

# %%
print(not False)
# Out:
# True

# %%
print(not (5 > 10))
# Out:
# True

# %%
# 변수: 어떤 값을 저장하는 공간
# 애완동물을 소개해 주세요~
animal = "고양이"
name = "해피"
age = 4
hobby = "낮잠"
is_adult = age >= 3

''' 여러 문장
주석 처리
한번에 주석 처리하고 싶은 줄 선택 후 command + /'''

print("우리 집 " + animal + "의 이름은 " + name + "예요")
hobby = "공놀이"
print(name + "는 " + str(age) + "살이며, " + hobby + "을 아주 좋아해요")
print(name, "는 ", age, "살이며, ", hobby, "을 아주 좋아해요")
print(name + "는 어른일까요? " + str(is_adult))
# Out:
# 우리 집 고양이의 이름은 해피예요
# 해피는 4살이며, 공놀이을 아주 좋아해요
# 해피 는  4 살이며,  공놀이 을 아주 좋아해요
# 해피는 어른일까요? True

# %%
# Quiz) 변수를 이용하여 다음 문장을 출력하시오
# 변수명: station
# 변수값: "사당", "신도림", "인천공항" 순서대로 입력
# 출력 문장: XX 행 열차가 들어오고 있습니다.

station = "사당"
print(station, "행 열차가 들어오고 있습니다.")

station = "신도림"
print(station, "행 열차가 들어오고 있습니다.")

station = "인천공항"
print(station, "행 열차가 들어오고 있습니다.")
# Out:
# 사당 행 열차가 들어오고 있습니다.
# 신도림 행 열차가 들어오고 있습니다.
# 인천공항 행 열차가 들어오고 있습니다.

# %%
print(2**3)
print(5%3) # 나머지 구하기
print(10%3)
print(5//3) # 몫
print(10//3)
print(10 > 3)
print(4 >= 7)
print(10 < 3)
print(5 <= 5)
# Out:
# 8
# 2
# 1
# 1
# 3
# True
# False
# False
# True

# %%
print(3 == 3) # 앞과 뒤가 값이 같다
print(4 == 2)
print(3 + 4 == 7)
# Out:
# True
# False
# True

# %%
print(1 != 3) # 앞과 뒤가 값이 같지 않다
print(not(1 != 3))

print((3 > 0) and (3 < 5))
print((3 > 0) & (3 < 5))

print((3 > 0) or (3 > 5))
print((3 > 0) | (3 > 5))

print(5 > 4 > 3)
print(5 > 4 > 7)
# Out:
# True
# False
# True
# True
# True
# True
# True
# False

# %%
print(2 + 3 * 4) # 14
print((2 + 3) * 4) # 20

number = 2 + 3 * 4 # 14
print(number)
number = number + 2 # 16
print(number)
number += 2 # 18
print(number)
number *=2 # 36
print(number)
number /= 2 # 18
print(number)
number -= 2 # 16
print(number)

number %= 5 # 1
print(number)
# Out:
# 14
# 20
# 14
# 16
# 18
# 36
# 18.0
# 16.0
# 1.0

# %%
print(abs(-5)) # 절대값, 5
print(pow(4, 2)) # 4^2, 16
print(max(5, 12)) # 둘 중 최대값
print(min(5, 12)) # 둘 중 최소값
print(round(3.14)) # 반올림한 값
print(round(4.99))

from math import * # math 라이브러리 안에 있는 모든 것을 이용
print(floor(4.99)) # 내림, 4
print(ceil(3.14)) # 올림, 4
print(sqrt(16)) # 제곱근, 4
# Out:
# 5
# 16.0
# 12
# 5
# 3
# 5
# 4
# 4
# 4.0

# %%
# 랜덤 함수, 난수
from random import * # random 라이브러리 이용

print(random()) # 0.0 이상 1.0 미만의 임의의 값 생성

print(random() * 10) # 0.0 이상 10.0 미만의 임의의 값 생성

print(int(random() * 10)) # 0 이상 10 미만의 임의의 값 생성

print(int(random() * 10) + 1) # 1 이상 10 이하의 임의의 값 생성

print(int(random() * 45) + 1) # 1 이상 45 이하의 임의의 값 생성

print(randrange(1, 46)) # 1 이상 46 미만의 임의의 값 생성

print(randint(1, 45)) # 1 이상 45 이하의 임의의 값 생성
# Out:
# 0.7212609435116287
# 6.622636479840626
# 6
# 4
# 42
# 1
# 21

# %%
# Quiz) 당신은 최근에 코딩 스터디 모임을 새로 만들었습니다.
# 월 4회 스터디 중 3번은 온라인, 1번은 오프라인으로 하기로 했습니다.
# 아래 조건에 맞는 오프라인 모임 날짜를 정해주는 프로그램을 작성하시오.

# 조건1: 랜덤으로 날짜를 뽑아야 함
# 조건2: 월별 날짜는 다름을 감안하여 최소 일수인 28 이내로 정함
# 조건3: 매월 1~3일은 스터디 준비를 해야 하므로 제외

# (출력문 예제)
# 오프라인 스터디 모임 날짜는 매월 x 일로 선정되었습니다.

# date = randrange(4, 29)
# date = randint(4, 28)
date = int((random() * 25) + 4)
print("오프라인 스터디 모임 날짜는 매월 " + str(date) + " 일로 선정되었습니다.")
date = int((random() * 25) + 4)
print("오프라인 스터디 모임 날짜는 매월", date, "일로 선정되었습니다.")
# Out:
# 오프라인 스터디 모임 날짜는 매월 23 일로 선정되었습니다.
# 오프라인 스터디 모임 날짜는 매월 23 일로 선정되었습니다.

# %%
sentence = "나는 소년입니다"
print(sentence)
sentence2 = "파이썬은 쉬워요"
print(sentence2)
sentence3 = """
나는 소년이고,
파이썬은 쉬워요
""" # """ 줄의 줄바꿈도 포함하여 총 4줄이 찍힌다
print(sentence3)
# Out:
# 나는 소년입니다
# 파이썬은 쉬워요
#
# 나는 소년이고,
# 파이썬은 쉬워요

# %%
# 슬라이싱
jumin = "990120-1234567"

print("성별: " + jumin[7]) # 7번째 값 출력
print("연: " + jumin[0:2]) # 0번째 이상 2 미만까지의 값 출력
print("월: " + jumin[2:4])
print("일: " + jumin[4:6])
print("생년월일: " + jumin[:6]) # 처음부터 6 미만까지
print("뒤 7자리: " + jumin[7:]) # 7번째부터 끝까지
print("뒤 7자리 (뒤에서부터): " + jumin[-7:])
# Out:
# 성별: 1
# 연: 99
# 월: 01
# 일: 20
# 생년월일: 990120
# 뒤 7자리: 1234567
# 뒤 7자리 (뒤에서부터): 1234567

# %%
# 문자열 처리 함수
python = "Python is Amazing"
print(python.lower()) # 문자열을 모두 소문자로
print(python.upper()) # 문자열을 모두 대문자로
print(python[0].isupper()) # 0번째가 대문자인지 묻는다
print(len(python)) # length, 전체 문자열의 길이 반환
print(python.replace("Python", "Java")) # 첫 번째 문자를 두 번째 문자로 대체하여 반환

print("")
index = python.index("n") # 문자열에서 n의 위치를 찾는 index 변수
print(index)
index = python.index("n", index + 1) # 6번째부터의 n의 위치 찾는 index 변수
print(index)

print("")
print(python.find("Java")) # 값이 문자열에 포함되어 있지 않으면 -1을 반환
# print(python.index("Java")) # 오류를 내면서 프로그램을 종료함
print("hi")

print("")
print(python.count("n")) # n이 총 몇 번 등장하는지
# Out:
# python is amazing
# PYTHON IS AMAZING
# True
# 17
# Java is Amazing
#
# 5
# 15
#
# -1
# hi
#
# 2

# %%
# 문자열 포맷

print("a" + "b")
print("a", "b")

# 방법 1
print("\n나는 %d살입니다." % 20) # d는 정수, 항상 정수만 넣을 수 있음
print("나는 %s을 좋아해요." % "파이썬") # s는 문자열(string)값을 의미
print("Apple은 %c로 시작해요." % "A") # c는 문자(character), 한 글자만 넣을 수 있음
# %s는 정수, 문자 상관없음
print("\n나는 %s살입니다." % 20)
print("나는 %s색과 %s색을 좋아해요." % ("파란", "빨간"))

# 방법 2
print("\n나는 {}살입니다.".format(20)) # format 값을 중괄호에 넣음
print("나는 {}색과 {}색을 좋아해요.".format("파란", "빨간"))
print("나는 {0}색과 {1}색을 좋아해요.".format("파란", "빨간"))
print("나는 {1}색과 {0}색을 좋아해요.".format("파란", "빨간"))

# 방법 3
print("\n나는 {age}살이며, {color}색을 좋아해요.".format(age = 20, color = "빨간")) # 변수처럼 선언하여 중괄호 안에 넣을 수 있음
print("나는 {age}살이며, {color}색을 좋아해요.".format(color = "빨간", age = 20))

# 방법 4 (v3.6 이상)
age = 20 # 직접 변수를 선언
color = "빨간"
print(f"\n나는 {age}살이며, {color}색을 좋아해요.") # 변수 값 가져다 쓰기 가능
# Out:
# ab
# a b
#
# 나는 20살입니다.
# 나는 파이썬을 좋아해요.
# Apple은 A로 시작해요.
#
# 나는 20살입니다.
# 나는 파란색과 빨간색을 좋아해요.
#
# 나는 20살입니다.
# 나는 파란색과 빨간색을 좋아해요.
# 나는 파란색과 빨간색을 좋아해요.
# 나는 빨간색과 파란색을 좋아해요.
#
# 나는 20살이며, 빨간색을 좋아해요.
# 나는 20살이며, 빨간색을 좋아해요.
#
# 나는 20살이며, 빨간색을 좋아해요.

# %%
# 탈출 문자
print("백문이 불여일견 \n백견이 불여일타") # \n, 줄바꿈

# 저는 "나도코딩"입니다.
print("\n저는 '나도코딩'입니다.")
print('저는 "나도코딩"입니다.')
print("저는 \"나도코딩\"입니다.") # 문장 내에서 따옴표
print("저는 \'나도코딩\'입니다.")

# \\, 문장 내에서 \
print("\n\\user\\minji")

#\r, 커서를 맨 앞으로 이동
print("Red Apple\rPine")

#\b, 백스페이스(한 글자 삭제)
print("Redd\bApple")

#\t, 탭
print("Red\tApple")
# Out:
# 백문이 불여일견
# 백견이 불여일타
#
# 저는 '나도코딩'입니다.
# 저는 "나도코딩"입니다.
# 저는 "나도코딩"입니다.
# 저는 '나도코딩'입니다.
#
# \user\minji
# PineApple
# RedApple
# Red	Apple

# %%
# Quiz) 사이트별로 비밀번호를 만들어 주는 프로그램을 작성하시오

# 예) http://naver.com
# 규칙1: http:// 부분은 제외 => naver.com
# 규칙2: 처음 만나는 점(.) 이후 부분은 제외 => naver
# 규칙3: 남은 글자 중 처음 세자리(nav) + 글자 개수(5) + 글자 내 'e' 개수(1) + '!'로 구성
# 예) 생성된 비밀번호: nav51!

url = "http://youtube.com"
my_str = url.replace("http://", "")
print(my_str)
my_str = my_str[:my_str.index(".")]
print(my_str)
password = my_str[:3] + str(len(my_str)) + str(my_str.count("e")) + "!"
print("{0} 의 비밀번호는 {1}입니다.".format(url, password))
# Out:
# youtube.com
# youtube
# http://youtube.com 의 비밀번호는 you71!입니다.

# %%
# 리스트 []

# 지하철 칸 별로 10명, 20명, 30명
subway1 = 10
subway2 = 20
subway3 = 30

subway =[10, 20, 30]
print(subway)

subway = ["유재석", "조세호", "박명수"]
print(subway)

# 조세호 씨가 몇 번째 칸에 타고 있는가?
print(subway.index("조세호"))

# 하하 씨가 다음 정류장에서 다음 칸에 탐
subway.append("하하") # 맨뒤에 하하를 추가함
print(subway)

# 정형돈 씨를 유재석 / 조세호 사이에 태움
subway.insert(1, "정형돈")
print(subway)

# 지하철에 있는 사람을 한 명씩 뒤에서 꺼냄
print(subway.pop()) # 뒤에서부터 하나씩 꺼냄
print(subway)

# print(subway.pop()) # 뒤에서부터 하나씩 꺼냄
# print(subway)

# print(subway.pop()) # 뒤에서부터 하나씩 꺼냄
# print(subway)

# 같은 이름의 사람이 몇 명 있는지 확인
subway.append("유재석")
print(subway)
print(subway.count("유재석"))

# 정렬도 가능
num_list = [5, 2, 4, 3, 1]
num_list.sort() # 정렬
print(num_list)

# 순서 뒤집기 가능
num_list.reverse()
print(num_list)

# 모두 지우기
# num_list.clear()
print(num_list)

# 다양한 자료형 함께 사용 가능
mix_list = ["조세호", 20, True]
print(mix_list)

# 리스트 확장
num_list.extend(mix_list)
print(num_list)
# Out:
# [10, 20, 30]
# ['유재석', '조세호', '박명수']
# 1
# ['유재석', '조세호', '박명수', '하하']
# ['유재석', '정형돈', '조세호', '박명수', '하하']
# 하하
# ['유재석', '정형돈', '조세호', '박명수']
# ['유재석', '정형돈', '조세호', '박명수', '유재석']
# 2
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]
# [5, 4, 3, 2, 1]
# ['조세호', 20, True]
# [5, 4, 3, 2, 1, '조세호', 20, True]

# %%
# dictionary, 사전
cabinet = {3:"유재석"} # 자료형
